# %% [markdown]
# 膨胀：结构元素中的1对应的元素 有1 就是1
#
# 腐蚀：结构元素中的1对应的元素 有0  就是0.全是0才为1
#
# 结构元素：只看1，0就默认没有
#
# 开操作：先腐蚀后膨胀
# 闭操作：先膨胀后腐蚀

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
